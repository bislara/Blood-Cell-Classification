# %% [markdown]
# <a href="https://colab.research.google.com/github/bislara/Blood-Cell-Classification/blob/master/Blood_Cell_Classification_PyTorch4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import os
import time

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


trainset = torchvision.datasets.ImageFolder(root = "/content/drive/My Drive/Blood_cells_dataset/TRAIN", transform = transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=4)

testset = torchvision.datasets.ImageFolder(root = "/content/drive/My Drive/Blood_cells_dataset/TEST", transform = transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, num_workers=4)

testsample = torchvision.datasets.ImageFolder(root = "/content/drive/My Drive/Blood_cells_dataset/TEST_SIMPLE", transform = transform)
test_sample_loader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, num_workers=4)

# %%
root_path = '/content/drive/My Drive/Blood_cells_dataset/TRAIN'
file_names = []
dir_names = []
root_names = []
for (root,dirs,files) in os.walk(root_path, topdown=True):
    file_names.append(files)
    dir_names.append(dirs)
    root_names.append(root)

classes = tuple(dir_names[0])

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
print("Input Size is ",images.size())
# Out:
# LYMPHOCYTE NEUTROPHIL NEUTROPHIL EOSINOPHIL
# Input Size is  torch.Size([4, 3, 240, 320])

# %%
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, in_fea = 3, out_fea = len(classes)):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(in_fea, 8, 5)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=1, padding=1)
        self.conv2 = nn.Conv2d(8, 12, 5)
        self.conv3 = nn.Conv2d(12, 20, 5)
        self.fc1 = nn.Linear(20 * 231 * 311, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, out_fea)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        # print("X size is: ",x.size())
        x = x.view(-1, 20 * 231 * 311)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
#check if cuda available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 

step = 0
loss_train = []
loss_val = []

#import the model
net = Net()
if torch.cuda.device_count() > 1:
  print("Let's use", torch.cuda.device_count(), "GPUs!")
  # dim = 0 [30, xxx] -> [10, ...], [10, ...], [10, ...] on 3 GPUs
  net = nn.DataParallel(net)
net = net.to(device)

# %%
print(device)
# Out:
# cuda:0

# %%
net = net.train()
min_loss = 100
patience = 20
training_loss_store = []
validation_loss_store = []

import torch.optim as optim

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
file = open('/content/drive/My Drive/Blood_cells_dataset/logs_test4_epoch100_with_max_pool3.txt', 'w')

# %%
print('training started.............................................')
file.write('training started.............................................\n')
start_time = time.time()
for epoch in range(50):  # loop over the dataset multiple times
    file.write('##############################TRAINING###############################\n')
    running_loss = 0.0
    loop_no=0
    for i, data in enumerate(trainloader, 0):
        step+=1
        loop_no+=1
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device),data[1].to(device)

        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        #print("Input Size is ",inputs.size())
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss_train.append(loss.item())
        training_loss_store.append([epoch, loss.item()])
        loss.backward()
        optimizer.step()
        

        # print statistics
        running_loss += loss.item()
        if i % 10 == 9:    # print every 10 mini-batches
            print('[%d, %5d] loss: %.3f' %(epoch + 1, i + 1, running_loss / 10))
            #log_loss_summary(logger, loss_train, step, prefix = 'train_')
            file.write('epoch = '+ str(epoch + 1) + '\t' +'step = '+ str(step) +'\t'+'train_loss = '+'\t'+str(np.mean(loss_train)) +'\n')
            loss_train = []
            running_loss = 0.0
            
    print('Finished training for epoch ' + str(epoch) + ' time taken = ' + str(time.time() - start_time))
    file.write('Finished training for epoch ' + str(epoch) + ' time taken = ' + str(time.time() - start_time) + '\n')
    file.write('##################################evaluation##############################\n')
    print('################################evaluation###########################\n')
    

    with torch.no_grad():
        val_loss = 0
        net.eval()
        
        for i, data in enumerate(test_sample_loader, 0):
            step+=1
            inputs, labels = data[0].to(device),data[1].to(device)
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss_val.append(loss.item())
            validation_loss_store.append([epoch, loss.item()])
            val_loss += loss
            
        val_loss = val_loss/float(i + 1)
        
        if val_loss < min_loss:
            min_loss = val_loss
            no_impr_epoch = 0
            
            #save the best model
            torch.save(net.state_dict(), 'training/epoch_' + str(epoch+1) + 'loss_' + str(val_loss) + '.pt')
            
            print('performance improved with validation loss ' + str(val_loss))
            file.write('--------------------------------------------------------------------\n')
            file.write('performance improved with validation loss =  ' + str(val_loss) + '\n')
            
            file.write('epoch = '+ str(epoch + 1) + '\t' +'step = '+ str(step) +'\t'+'val_loss = '+'\t'+str(np.mean(loss_val)) +'\n')
            file.write('--------------------------------------------------------------------\n\n')
            #log_loss_summary(logger, loss_val, step, prefix="val_")
            loss_val = []
        else:
            no_impr_epoch += 1
            print('no improvement with prev best model ' + str(no_impr_epoch) + 'th')
            file.write('no improvement with prev best model ' + str(no_impr_epoch) + 'th \n')
            
        if no_impr_epoch > patience:
            print('stop training')
            file.write('stop training')
            break

print('Finished Training................................................')
file.write('Finished Training................................................\n')
end_time = time.time()
file.write('Training time:- ' + str(end_time - start_time))
file.close()
# Out:
# training started.............................................
# [1,    10] loss: 1.386
# [1,    20] loss: 1.383
# [1,    30] loss: 1.381
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-f4921474f690> in <module>()
#      25
#      26         # print statistics
# ---> 27         running_loss += loss.item()
#      28         if i % 10 == 9:    # print every 10 mini-batches
#      29             print('[%d, %5d] loss: %.3f' %(epoch + 1, i + 1, running_loss / 10))
#
# KeyboardInterrupt:

# %%
#Release all unoccupied cached memory in GPU
if(torch.cuda.is_available()):
    torch.cuda.empty_cache()

# %%
PATH = "training/epoch_3loss_tensor(1.2402, device='cuda:0').pt"
model = Net()
model.load_state_dict(torch.load(PATH))
model.eval()

dataiter = iter(testloader)
images, labels = dataiter.next()


# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print('Ground Truth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))


outputs = model(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
i = outputs.detach().numpy()
#print('Scores:-', i)
for j in range(len(classes)):
    print(classes[j], ':- ', i[0, j])
# Out:
# Ground Truth:  MONOCYTE EOSINOPHIL MONOCYTE MONOCYTE
# Predicted:  NEUTROPHIL LYMPHOCYTE NEUTROPHIL MONOCYTE
# LYMPHOCYTE :-  0.065295264
# NEUTROPHIL :-  0.28955674
# MONOCYTE :-  -0.27457994
# EOSINOPHIL :-  -0.09247272

# %%
PATH = "training/epoch_3loss_tensor(1.2402, device='cuda:0').pt"
model = Net()
model.load_state_dict(torch.load(PATH))
model.eval()

dataiter = iter(trainloader)
images, labels = dataiter.next()


# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print('Ground Truth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))


outputs = model(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
i = outputs.detach().numpy()
#print('Scores:-', i)
for j in range(len(classes)):
    print(classes[j], ':- ', i[0, j])
# Out:
# Ground Truth:  NEUTROPHIL EOSINOPHIL LYMPHOCYTE MONOCYTE
# Predicted:  NEUTROPHIL NEUTROPHIL MONOCYTE MONOCYTE
# LYMPHOCYTE :-  -0.025310352
# NEUTROPHIL :-  0.93180406
# MONOCYTE :-  -0.42236063
# EOSINOPHIL :-  -0.44137016

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data[0], data[1]
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        print("Total is ",total)

print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))
# Out:
# Total is  4
# Total is  8
# Total is  12
# Total is  16
# Total is  20
# Total is  24
# Total is  28
# Total is  32
# Total is  36
# Total is  40
# Total is  44
# Total is  48
# Total is  52
# Total is  56
# Total is  60
# Total is  64
# Total is  68
# Total is  72
# Total is  76
# Total is  80
# Total is  84
# Total is  88
# Total is  92
# Total is  96
# Total is  100
# Total is  104
# Total is  108
# Total is  112
# Total is  116
# Total is  120
# Total is  124
# Total is  128
# Total is  132
# Total is  136
# Total is  140
# Total is  144
# Total is  148
# Total is  152
# Total is  156
# Total is  160
# Total is  164
# Total is  168
# Total is  172
# Total is  176
# Total is  180
# Total is  184
# Total is  188
# Total is  192
# Total is  196
# Total is  200
# Total is  204
# Total is  208
# Total is  212
# Total is  216
# Total is  220
# Total is  224
# Total is  228
# Total is  232
# Total is  236
# Total is  240
# Total is  244
# Total is  248
# Total is  252
# Total is  256
# Total is  260
# Total is  264
# Total is  268
# Total is  272
# Total is  276
# Total is  280
# Total is  284
# Total is  288
# Total is  292
# Total is  296
# Total is  300
# Total is  304
# Total is  308
# Total is  312
# Total is  316
# Total is  320
# Total is  324
# Total is  328
# Total is  332
# Total is  336
# Total is  340
# Total is  344
# Total is  348
# Total is  352
# Total is  356
# Total is  360
# Total is  364
# Total is  368
# Total is  372
# Total is  376
# Total is  380
# Total is  384
# Total is  388
# Total is  392
# Total is  396
# Total is  400
# Total is  404
# Total is  408
# Total is  412
# Total is  416
# Total is  420
# Total is  424
# Total is  428
# Total is  432
# Total is  436
# Total is  440
# Total is  444
# Total is  448
# Total is  452
# Total is  456
# Total is  460
# Total is  464
# Total is  468
# Total is  472
# Total is  476
# Total is  480
# Total is  484
# Total is  488
# Total is  492
# Total is  496
# Total is  500
# Total is  504
# Total is  508
# Total is  512
# Total is  516
# Total is  520
# Total is  524
# Total is  528
# Total is  532
# Total is  536
# Total is  540
# Total is  544
# Total is  548
# Total is  552
# Total is  556
# Total is  560
# Total is  564
# Total is  568
# Total is  572
# Total is  576
# Total is  580
# Total is  584
# Total is  588
# Total is  592
# Total is  596
# Total is  600
# Total is  604
# Total is  608
# Total is  612
# Total is  616
# Total is  620
# Total is  624
# Total is  628
# Total is  632
# Total is  636
# Total is  640
# Total is  644
# Total is  648
# Total is  652
# Total is  656
# Total is  660
# Total is  664
# Total is  668
# Total is  672
# Total is  676
# Total is  680
# Total is  684
# Total is  688
# Total is  692
# Total is  696
# Total is  700
# Total is  704
# Total is  708
# Total is  712
# Total is  716
# Total is  720
# Total is  724
# Total is  728
# Total is  732
# Total is  736
# Total is  740
# Total is  744
# Total is  748
# Total is  752
# Total is  756
# Total is  760
# Total is  764
# Total is  768
# Total is  772
# Total is  776
# Total is  780
# Total is  784
# Total is  788
# Total is  792
# Total is  796
# Total is  800
# Total is  804
# Total is  808
# Total is  812
# Total is  816
# Total is  820
# Total is  824
# Total is  828
# Total is  832
# Total is  836
# Total is  840
# Total is  844
# Total is  848
# Total is  852
# Total is  856
# Total is  860
# Total is  864
# Total is  868
# Total is  872
# Total is  876
# Total is  880
# Total is  884
# Total is  888
# Total is  892
# Total is  896
# Total is  900
# Total is  904
# Total is  908
# Total is  912
# Total is  916
# Total is  920
# Total is  924
# Total is  928
# Total is  932
# Total is  936
# Total is  940
# Total is  944
# Total is  948
# Total is  952
# Total is  956
# Total is  960
# Total is  964
# Total is  968
# Total is  972
# Total is  976
# Total is  980
# Total is  984
# Total is  988
# Total is  992
# Total is  996
# Total is  1000
# Total is  1004
# Total is  1008
# Total is  1012
# Total is  1016
# Total is  1020
# Total is  1024
# Total is  1028
# Total is  1032
# Total is  1036
# Total is  1040
# Total is  1044
# Total is  1048
# Total is  1052
# Total is  1056
# Total is  1060
# Total is  1064
# Total is  1068
# Total is  1072
# Total is  1076
# Total is  1080
# Total is  1084
# Total is  1088
# Total is  1092
# Total is  1096
# Total is  1100
# Total is  1104
# Total is  1108
# Total is  1112
# Total is  1116
# Total is  1120
# Total is  1124
# Total is  1128
# Total is  1132
# Total is  1136
# Total is  1140
# Total is  1144
# Total is  1148
# Total is  1152
# Total is  1156
# Total is  1160
# Total is  1164
# Total is  1168
# Total is  1172
# Total is  1176
# Total is  1180
# Total is  1184
# Total is  1188
# Total is  1192
# Total is  1196
# Total is  1200
# Total is  1204
# Total is  1208
# Total is  1212
# Total is  1216
# Total is  1220
# Total is  1224
# Total is  1228
# Total is  1232
# Total is  1236
# Total is  1240
# Total is  1244
# Total is  1248
# Total is  1252
# Total is  1256
# Total is  1260
# Total is  1264
# Total is  1268
# Total is  1272
# Total is  1276
# Total is  1280
# Total is  1284
# Total is  1288
# Total is  1292
# Total is  1296
# Total is  1300
# Total is  1304
# Total is  1308
# Total is  1312
# Total is  1316
# Total is  1320
# Total is  1324
# Total is  1328
# Total is  1332
# Total is  1336
# Total is  1340
# Total is  1344
# Total is  1348
# Total is  1352
# Total is  1356
# Total is  1360
# Total is  1364
# Total is  1368
# Total is  1372
# Total is  1376
# Total is  1380
# Total is  1384
# Total is  1388
# Total is  1392
# Total is  1396
# Total is  1400
# Total is  1404
# Total is  1408
# Total is  1412
# Total is  1416
# Total is  1420
# Total is  1424
# Total is  1428
# Total is  1432
# Total is  1436
# Total is  1440
# Total is  1444
# Total is  1448
# Total is  1452
# Total is  1456
# Total is  1460
# Total is  1464
# Total is  1468
# Total is  1472
# Total is  1476
# Total is  1480
# Total is  1484
# Total is  1488
# Total is  1492
# Total is  1496
# Total is  1500
# Total is  1504
# Total is  1508
# Total is  1512
# Total is  1516
# Total is  1520
# Total is  1524
# Total is  1528
# Total is  1532
# Total is  1536
# Total is  1540
# Total is  1544
# Total is  1548
# Total is  1552
# Total is  1556
# Total is  1560
# Total is  1564
# Total is  1568
# Total is  1572
# Total is  1576
# Total is  1580
# Total is  1584
# Total is  1588
# Total is  1592
# Total is  1596
# Total is  1600
# Total is  1604
# Total is  1608
# Total is  1612
# Total is  1616
# Total is  1620
# Total is  1624
# Total is  1628
# Total is  1632
# Total is  1636
# Total is  1640
# Total is  1644
# Total is  1648
# Total is  1652
# Total is  1656
# Total is  1660
# Total is  1664
# Total is  1668
# Total is  1672
# Total is  1676
# Total is  1680
# Total is  1684
# Total is  1688
# Total is  1692
# Total is  1696
# Total is  1700
# Total is  1704
# Total is  1708
# Total is  1712
# Total is  1716
# Total is  1720
# Total is  1724
# Total is  1728
# Total is  1732
# Total is  1736
# Total is  1740
# Total is  1744
# Total is  1748
# Total is  1752
# Total is  1756
# Total is  1760
# Total is  1764
# Total is  1768
# Total is  1772
# Total is  1776
# Total is  1780
# Total is  1784
# Total is  1788
# Total is  1792
# Total is  1796
# Total is  1800
# Total is  1804
# Total is  1808
# Total is  1812
# Total is  1816
# Total is  1820
# Total is  1824
# Total is  1828
# Total is  1832
# Total is  1836
# Total is  1840
# Total is  1844
# Total is  1848
# Total is  1852
# Total is  1856
# Total is  1860
# Total is  1864
# Total is  1868
# Total is  1872
# Total is  1876
# Total is  1880
# Total is  1884
# Total is  1888
# Total is  1892
# Total is  1896
# Total is  1900
# Total is  1904
# Total is  1908
# Total is  1912
# Total is  1916
# Total is  1920
# Total is  1924
# Total is  1928
# Total is  1932
# Total is  1936
# Total is  1940
# Total is  1944
# Total is  1948
# Total is  1952
# Total is  1956
# Total is  1960
# Total is  1964
# Total is  1968
# Total is  1972
# Total is  1976
# Total is  1980
# Total is  1984
# Total is  1988
# Total is  1992
# Total is  1996
# Total is  2000
# Total is  2004
# Total is  2008
# Total is  2012
# Total is  2016
# Total is  2020
# Total is  2024
# Total is  2028
# Total is  2032
# Total is  2036
# Total is  2040
# Total is  2044
# Total is  2048
# Total is  2052
# Total is  2056
# Total is  2060
# Total is  2064
# Total is  2068
# Total is  2072
# Total is  2076
# Total is  2080
# Total is  2084
# Total is  2088
# Total is  2092
# Total is  2096
# Total is  2100
# Total is  2104
# Total is  2108
# Total is  2112
# Total is  2116
# Total is  2120
# Total is  2124
# Total is  2128
# Total is  2132
# Total is  2136
# Total is  2140
# Total is  2144
# Total is  2148
# Total is  2152
# Total is  2156
# Total is  2160
# Total is  2164
# Total is  2168
# Total is  2172
# Total is  2176
# Total is  2180
# Total is  2184
# Total is  2188
# Total is  2192
# Total is  2196
# Total is  2200
# Total is  2204
# Total is  2208
# Total is  2212
# Total is  2216
# Total is  2220
# Total is  2224
# Total is  2228
# Total is  2232
# Total is  2236
# Total is  2240
# Total is  2244
# Total is  2248
# Total is  2252
# Total is  2256
# Total is  2260
# Total is  2264
# Total is  2268
# Total is  2272
# Total is  2276
# Total is  2280
# Total is  2284
# Total is  2288
# Total is  2292
# Total is  2296
# Total is  2300
# Total is  2304
# Total is  2308
# Total is  2312
# Total is  2316
# Total is  2320
# Total is  2324
# Total is  2328
# Total is  2332
# Total is  2336
# Total is  2340
# Total is  2344
# Total is  2348
# Total is  2352
# Total is  2356
# Total is  2360
# Total is  2364
# Total is  2368
# Total is  2372
# Total is  2376
# Total is  2380
# Total is  2384
# Total is  2388
# Total is  2392
# Total is  2396
# Total is  2400
# Total is  2404
# Total is  2408
# Total is  2412
# Total is  2416
# Total is  2420
# Total is  2424
# Total is  2428
# Total is  2432
# Total is  2436
# Total is  2440
# Total is  2444
# Total is  2448
# Total is  2452
# Total is  2456
# Total is  2460
# Total is  2464
# Total is  2468
# Total is  2472
# Total is  2476
# Total is  2480
# Total is  2484
# Total is  2488
# Total is  2492
# Total is  2496
# Total is  2500
# Total is  2504
# Total is  2506
# Accuracy of the network on the test images: 41 %

# %%
class_correct = list(0. for i in range(4))
class_total = list(0. for i in range(4))
with torch.no_grad():
    for data in testloader:
        images, labels = data[0], data[1]
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels)
        for i in range(1):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

#file = open('result_logs.txt', 'w')
for i in range(4):
    print('Accuracy of %5s : %2d %%' % (classes[i], 100 * class_correct[i] / class_total[i]))
    #file.write('Accuracy of' + classes[i] + ':' + '\t' + str(100 * class_correct[i] / class_total[i]) +'%'+'\n')
# Out:
# Accuracy of LYMPHOCYTE : 39 %
# Accuracy of NEUTROPHIL : 49 %
# Accuracy of MONOCYTE : 73 %
# Accuracy of EOSINOPHIL :  2 %

# %%
file.close()

# %%
torch.save(net.state_dict(), 'model.pt')
